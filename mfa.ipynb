# %% [markdown]
# # Model-Free Analysis

# %% [markdown]
# This notebook will investigate the fixation distributions generated by examples/example4_new/addm_gen_data.ipynb using model-free analyses as described by Eum et al. (2023).

# %%
import pandas as pd

data_dict = pd.read_pickle('/Users/braydenchien/Desktop/Enkavilab/efficient-fpt/examples/example4_new/addm_data_20251015-163921.pkl')

# %%
for key in data_dict.keys():
    print(f'data_dict["{key}"] is type {type(data_dict[key])}')
# Out:
# data_dict["mu_array_padded_data"] is type <class 'numpy.ndarray'>
# data_dict["sacc_array_padded_data"] is type <class 'numpy.ndarray'>
# data_dict["d_data"] is type <class 'numpy.ndarray'>
# data_dict["decision_data"] is type <class 'numpy.ndarray'>
# data_dict["r1_data"] is type <class 'numpy.ndarray'>
# data_dict["r2_data"] is type <class 'numpy.ndarray'>
# data_dict["flag_data"] is type <class 'numpy.ndarray'>
# data_dict["eta"] is type <class 'float'>
# data_dict["kappa"] is type <class 'float'>
# data_dict["sigma"] is type <class 'int'>
# data_dict["a"] is type <class 'float'>
# data_dict["b"] is type <class 'float'>
# data_dict["x0"] is type <class 'float'>
# data_dict["T"] is type <class 'float'>
# data_dict["gamma_shape_param"] is type <class 'int'>
# data_dict["gamma_scale_param"] is type <class 'float'>

# %%
data_dict['sacc_array_padded_data'][0]
# Out:
# array([0.        , 0.56294376, 1.35037886, 2.07224015, 2.30662596,
#        3.1307183 , 3.32310599, 0.        , 0.        , 0.        ,
#        0.        , 0.        ])
